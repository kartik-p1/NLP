474, 1985, 2150, 1416, 2230, 64, 222, 2338, 96, 2345, 1873, 2165, 598, 1164, 240, 187, 978, 2284, 607, 1413, 1505, 143, 2038, 1967, 2157, 2248, 163, 1617, 361, 2198, 1724, 112, 2127, 1019, 279, 1010, 2332, 1392, 233, 599, 1591, 982, 125, 555, 683, 2349, 1475, 1136, 1867, 133, 1002, 1803, 1973, 61, 2089, 481, 615, 262, 1368, 1152, 1823, 1953, 1685, 1748, 783, 2353, 1993, 360, 1426, 2288, 1951, 1886, 2197, 1080, 1273, 1876, 423, 1132, 2156, 1325, 1517, 1589, 92, 492, 1841, 1202, 964, 205, 1530, 1952, 1825, 2385, 1645, 1404, 5, 547, 175, 488, 2115, 1462, 1186, 2173, 1381, 933, 1649, 177, 1907, 1609, 337, 1501, 2013, 577, 620, 6, 190, 490, 2283, 1280, 451, 708, 1979, 295, 1337, 1214, 2298, 2049, 1812, 49, 1142, 992, 1249, 1627, 2040, 1939, 1459, 1537, 1125, 1100, 887, 774, 1814, 1430, 376, 1160, 107, 63, 2314, 1282, 561, 517, 769, 1864, 2262, 970, 466, 797, 484, 1299, 83]

# %%
print(len(random_indices))
# Out:
# 1000

# %%
def count_sentences_and_get_random_sentences(file_path):
    # Read the content of the file
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()

    # Split the content into sentences based on new lines
    sentences = content.split('\n')

    # Get the sentences at the random indices
    random_sentences_hindi = [sentences[idx] for idx in random_indices]

    return random_sentences_hindi

file_path = '/kaggle/input/testdatasets/test.en'
gt_sentences_eng = count_sentences_and_get_random_sentences(file_path)

# %%
def count_sentences_and_get_random_sentences(file_path):
    # Read the content of the file
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()

    # Split the content into sentences based on new lines
    sentences = content.split('\n')

    # Get the sentences at the random indices
    random_sentences_hindi = [sentences[idx] for idx in random_indices]

    return random_sentences_hindi

file_path = '/kaggle/input/testdatasets/test.hi'
gt_sentences_hi = count_sentences_and_get_random_sentences(file_path)

# %%
def count_sentences_and_get_random_sentences(file_path):
    # Read the content of the file
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()

    # Split the content into sentences based on new lines
    sentences = content.split('\n')

    # Get the sentences at the random indices
    random_sentences_hindi = [sentences[idx] for idx in random_indices]

    return random_sentences_hindi

file_path = '/kaggle/input/testdatasets/test.gu'
gt_sentences_gu = count_sentences_and_get_random_sentences(file_path)

# %%
# !pip install rouge

# %%
file_path = "output.txt"
with open(file_path, "w") as file:
    # Write each string in the list to the file
    for string in gt_sentences_hi:
        file.write(string + "\n")
with open('/kaggle/working/output.txt', "r") as file:
    # Write each string in the list to the file
    reference = file.readlines()
with open('/kaggle/input/translations/en_to_hi2.txt', "r") as file:
    # Write each string in the list to the file
    candidate = file.readlines()

# %%
from rouge import Rouge
import nltk
from nltk.translate.bleu_score import corpus_bleu

# %% [markdown]
# ***BLEU and Rouge Score of english to hindi***

# %% [markdown]
# ****

# %%
bleu_score = corpus_bleu(reference, candidate)
print(f"BLEU score: {bleu_score}")
# Out:
# BLEU score: 0.7388634275993535
# /opt/conda/lib/python3.10/site-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
rouge = Rouge()
scores = rouge.get_scores(reference, candidate, avg = True)
print(scores)
# Out:
# {'rouge-1': {'r': 0.6329865530366104, 'p': 0.6288150136800152, 'f': 0.627680801383218}, 'rouge-2': {'r': 0.40207507046133095, 'p': 0.4002030315379105, 'f': 0.3990326517540273}, 'rouge-l': {'r': 0.598347168996381, 'p': 0.5940687535816785, 'f': 0.593194695790886}}

# %%
file_path = "output.txt"
with open(file_path, "w") as file:
    # Write each string in the list to the file
    for string in gt_sentences_hi:
        file.write(string + "\n")
with open('/kaggle/working/output.txt', "r") as file:
    # Write each string in the list to the file
    reference = file.readlines()
with open('/kaggle/input/translations/gu_to_hi2.txt', "r") as file:
    # Write each string in the list to the file
    candidate = file.readlines()

# %% [markdown]
# # Bleu and Rouge score of gujarati to hindi

# %%
bleu_score = corpus_bleu(reference, candidate)
print(f"BLEU score: {bleu_score}")
rouge = Rouge()
scores = rouge.get_scores(reference, candidate, avg = True)
print(scores)
# Out:
# BLEU score: 0.7351850459889806
# {'rouge-1': {'r': 0.5999062352592793, 'p': 0.6009868596150384, 'f': 0.5966329929700883}, 'rouge-2': {'r': 0.3708017687534632, 'p': 0.37244180047233466, 'f': 0.3690862404237738}, 'rouge-l': {'r': 0.56947263203766, 'p': 0.5702156619113888, 'f': 0.5662887626503976}}

# %%
file_path = "output.txt"
with open(file_path, "w") as file:
    # Write each string in the list to the file
    for string in gt_sentences_gu:
        file.write(string + "\n")
with open('/kaggle/working/output.txt', "r") as file:
    # Write each string in the list to the file
    reference = file.readlines()
with open('/kaggle/input/translations/hi_to_gu2.txt', "r") as file:
    # Write each string in the list to the file
    candidate = file.readlines()

# %% [markdown]
# # Bleu and Rouge score of hindi to gujrati

# %%
bleu_score = corpus_bleu(reference, candidate)
print(f"BLEU score: {bleu_score}")
rouge = Rouge()
scores = rouge.get_scores(reference, candidate, avg = True)
print(scores)
# Out:
# BLEU score: 0.7425928049423067
# {'rouge-1': {'r': 0.5458101723950416, 'p': 0.5386586555389273, 'f': 0.5391554775100795}, 'rouge-2': {'r': 0.2888927669903467, 'p': 0.285730071158188, 'f': 0.28559002813158146}, 'rouge-l': {'r': 0.5234783178407783, 'p': 0.5165394232786775, 'f': 0.5170926282539907}}

# %%
file_path = "output.txt"
with open(file_path, "w") as file:
    # Write each string in the list to the file
    for string in gt_sentences_eng:
        file.write(string + "\n")
with open('/kaggle/working/output.txt', "r") as file:
    # Write each string in the list to the file
    reference = file.readlines()
with open('/kaggle/input/translations/hi_to_en2.txt', "r") as file:
    # Write each string in the list to the file
    candidate = file.readlines()

# %% [markdown]
# # Bleu And Rouge score of hindi to english

# %%
bleu_score = corpus_bleu(reference, candidate)
print(f"BLEU score: {bleu_score}")
rouge = Rouge()
scores = rouge.get_scores(reference, candidate, avg = True)
print(scores)
# Out:
# BLEU score: 0.6978451098160566
# {'rouge-1': {'r': 0.6835515335711193, 'p': 0.6877613140829009, 'f': 0.6825310630262618}, 'rouge-2': {'r': 0.454663709624105, 'p': 0.45902740228301564, 'f': 0.45452456140611386}, 'rouge-l': {'r': 0.6546590314587396, 'p': 0.6589491008462529, 'f': 0.653852478321476}}
