# %%
with open('/kaggle/input/texttt/output.txt', "r") as file:
    # Write each string in the list to the file
    reference = file.readlines()
with open('/kaggle/input/texttt/output2.txt', "r") as file:
# Write each string in the list to the file
    candidate = file.readlines()

# %%
# !pip install rouge
# Out:
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from rouge) (1.16.0)
# Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1

# %%
from rouge import Rouge
import nltk
from nltk.translate.bleu_score import corpus_bleu

# %%
from nltk.translate.bleu_score import corpus_bleu
from rouge import Rouge

# Calculate BLEU score
bleu_score = corpus_bleu(reference, candidate)
print(f"BLEU score: {bleu_score}")
# Out:
# BLEU score: 0.7503982023554671
# /opt/conda/lib/python3.10/site-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
rouge = Rouge()
scores = rouge.get_scores(reference, candidate, avg = True)
print(scores)
# Out:
# {'rouge-1': {'r': 0.551159133916517, 'p': 0.5062877492358483, 'f': 0.5218780500442283}, 'rouge-2': {'r': 0.2928414573605978, 'p': 0.26955960688473324, 'f': 0.2773558262957637}, 'rouge-l': {'r': 0.5117715676630924, 'p': 0.4701192295028163, 'f': 0.4846182042506228}}
