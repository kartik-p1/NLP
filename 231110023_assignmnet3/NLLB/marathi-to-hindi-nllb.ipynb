# %%
import random

def count_sentences_and_get_random_sentences(file_path):
    # Read the content of the file
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()

    # Split the content into sentences based on new lines
    sentences = content.split('\n')

    # Calculate the total number of sentences
    total_sentences = len(sentences)

    # Generate 1000 random indices
    random_indices = random.sample(range(total_sentences), 1000)

    # Get the sentences at the random indices
    random_sentences = [sentences[idx] for idx in random_indices]

    return random_indices, random_sentences

# Replace 'file_path' with the path to your .en file
file_path = '/kaggle/input/databeta/test.mr'
random_indices, random_sentences = count_sentences_and_get_random_sentences(file_path)

# # Print the random indices and corresponding sentences
# for idx, sentence in zip(random_indices, random_sentences):
#     print(f"Index: {idx}, Sentence: {sentence.strip()}")

# %%
import random

def count_sentences_and_get_random_sentences(file_path):
    # Read the content of the file
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()

    # Split the content into sentences based on new lines
    sentences = content.split('\n')

    # Get the sentences at the random indices
    random_sentences_hindi = [sentences[idx] for idx in random_indices]

    return random_sentences_hindi

file_path = '/kaggle/input/databeta/test.hi'
random_sentences_marathi = count_sentences_and_get_random_sentences(file_path)

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained(
    "facebook/nllb-200-distilled-600M", src_lang="mar_Deva"
)
model = AutoModelForSeq2SeqLM.from_pretrained("facebook/nllb-200-distilled-600M")
# model = model.to('cuda')
stored_sentence_from_mr_to_hi = []
for sentence in random_sentences:
    article = sentence
    inputs = tokenizer(article, return_tensors="pt")

    translated_tokens = model.generate(
        **inputs, forced_bos_token_id=tokenizer.lang_code_to_id["hin_Deva"], max_length=30
    )
    var = tokenizer.batch_decode(translated_tokens, skip_special_tokens=True)[0]
    print(var)
    stored_sentence_from_mr_to_hi.append(var)
print(stored_sentence_from_mr_to_hi)
# Out:
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/3.55k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]
# ...

# %%
hindi_from_model = stored_sentence_from_mr_to_hi
print(len(hindi_from_model))
# Out:
# 1000

# %%
import random

def count_sentences_and_get_random_sentences(file_path):
    # Read the content of the file
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()

    # Split the content into sentences based on new lines
    sentences = content.split('\n')

    # Get the sentences at the random indices
    random_sentences_hindi = [sentences[idx] for idx in random_indices]

    return random_sentences_hindi

file_path = '/kaggle/input/databeta/test.hi'
ground_truth_hindi = count_sentences_and_get_random_sentences(file_path)

# %%
print(hindi_from_model[0])
print(ground_truth_hindi[0])
# Out:
# यह परीक्षा केवल उस पर आधारित होगी जो आपने एक साल में किया है।
# आप जो exam देने जा रहे हैं, वो साल भर में आपने जो पढ़ाई की है, उसकी exam है।

# %%
# !pip install rouge
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ...

# %%
# !pip install py-rouge
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ...

# %%
from rouge import Rouge
import nltk
from nltk.translate.bleu_score import corpus_bleu

# %%
print(ground_truth_hindi)
# print(hindi_from_model)
# Out:
# ['आप जो exam देने जा रहे हैं, वो साल भर में आपने जो पढ़ाई की है, उसकी exam है।', 'इससे, आप आसानी से वाराणसी जा सकते हैं और भगवान शिव का आशीर्वाद पा सकते हैं।', 'प्रधानमंत्री ने कहा कि आईक्यू (बौद्धिक कौशल) और ईक्यू (भावनात्मक कौशल), दोनों का छात्र जीवन में बहुत महत्व होता है।', 'प्रधानमंत्री श्री मोदी ने कहा, ‘मैं 1 जून को सिंगापुर के राष्ट्रपति हलीमा याकोब से मुलाकात करूंगा।', 'हमारी संस्कृति को नीचा दिखा कर हम में हीन-भावना पैदा करना, यह काम निरंतर चलता रहता था।', 'उन्होंने कहा कि आज ‘आईपीपीबी’ का शुभारंभ किया जाना इस उद्देश्य की पूर्ति करने की दिशा में एक और अहम कदम है।', 'सुरक्षा एवं रक्षा सहयोग ने हमारे संबंधों को उभरता हुआ नया आयाम दिया है।', 'उन्होंने सभी अधिकारियों से अपने संबंधित विभागों में सरकारी ई-बाज़ार (जीआईएम) को अपनाने की गति को बढ़ाने का लिए आग्रह किया।', 'हम पवन ऊर्जा के चौथे सबसे बड़े उत्\u200dपादक और सौर ऊर्जा के पांचवें सबसे बड़े उत्\u200dपादक हैं।', 'उन्होंने कहा कि यह पुरस्कार उस समय दिया जा रहा है, जब देश महात्मा गांधी की 150वीं जयंती मना रहा है।', '7. परस्\u20
# ...

# %%
from nltk.translate.bleu_score import corpus_bleu
from rouge import Rouge

# Sample lists of sentences
reference_sentences = ground_truth_hindi
candidate_sentences = hindi_from_model

# Calculate BLEU score
bleu_score = corpus_bleu(reference_sentences, candidate_sentences)
print(f"BLEU score: {bleu_score}")
# Out:
# BLEU score: 0.7454234926863361
# {}

# %%
# Out:
# {}

# %%
# with open("/kaggle/input/filesssssssssss/temp3.txt", "w") as file:
#     # Write each string in the list to the file
#     for string in reference_sentences:
#         file.write(string + "\n")
        
# with open("/kaggle/input/filesssssssssss/temp4.txt", "w") as file:
#     # Write each string in the list to the file
#     for string in candidate_sentences:
#         file.write(string + "\n")

# %%
file_path = "output.txt"

# Open the file in write mode
with open(file_path, "w") as file:
    # Write each string in the list to the file
    for string in reference_sentences:
        file.write(string + "\n")
file_path = "output2.txt"

# Open the file in write mode
with open(file_path, "w") as file:
    # Write each string in the list to the file
    for string in candidate_sentences:
        file.write(string + "\n")

# %%
with open('/kaggle/working/output.txt', "r") as file:
    # Write each string in the list to the file
    reference = file.readlines()
